# %% [markdown]
# Author: Nikko V. salcedo
# This is a classification model development using keras and tensorflow to detect hurricane damage using satellite images.
#
# Available dataset:
# Training - 10,0000
# Validation - 2,000
# Test - 9,000

# %% [markdown]
# # Part 1. Import all needed packages

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, classification_report, precision_recall_curve
import seaborn as sns
import tensorflow as tf
import numpy as np
import os
import PIL
import PIL.Image
import random
import matplotlib.pyplot as plt
sns.set()

# %% [markdown]
# # Part 2. Pre-procesing

# %%
# Dataset Image paths
TEST_LOC= "../../datasets/sat_images/test_another"
TRAIN_LOC = "../../datasets/sat_images/train_another"
VAL_LOC = "../../datasets/sat_images/validation_another"

#Other global variables:
IMG_SIZE = (128,128)
BATCH_SIZE = 150
classes = {'no_damage':0, 'damage': 1,}

#Image Data Generator Objects

""" 
Augmentations done on trianing data:
1. rotation
2. zoom
3. reflect
4. vertical flip
5. horizontal flip
6. rescale

This is to avoid overfitting
"""
train_idg = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=360,
    zoom_range=0.5,
    fill_mode='reflect',
    horizontal_flip=True,
    vertical_flip=True,
    rescale=1.0/255
)

test_idg =tf.keras.preprocessing.image.ImageDataGenerator( rescale=1.0/255)

#creating the datasets

train_gen = train_idg.flow_from_directory(TRAIN_LOC, IMG_SIZE,
                                         class_mode='binary', classes=classes,
                                         color_mode='rgb', shuffle=False,
                                         batch_size=BATCH_SIZE
                                         )

val_gen = train_idg.flow_from_directory(VAL_LOC, IMG_SIZE,
                                         class_mode='binary', classes=classes,
                                         color_mode='rgb', shuffle=False,
                                         batch_size=BATCH_SIZE
                                         )
test_gen = test_idg.flow_from_directory(TEST_LOC, IMG_SIZE,
                                         class_mode='binary', classes=classes,
                                         color_mode='rgb', shuffle=False,
                                         batch_size=1
                                         )
# Out:
# Found 10000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Found 9000 images belonging to 2 classes.

# %% [markdown]
# ### Some functions for unpacking and viewing the data

# %%
def view_generator_data(gen, n):
    data = [next(gen) for _ in range(n)]
    data = list(zip(*data))
    X, y = data
    X = np.concatenate(X, axis=0)
    y = np.concatenate(y, axis=0)
    return X, y

def view_images(X, y, n=None):
    n = n or len(X)
    for i in range(n):
        plt.imshow(X[i])
        plt.grid(None)
        plt.show()
        print('Label: ', y[i])
test_gen.__len__()
# Out:
# 9000

# %% [markdown]
# ## Loading sample images for "damaged" class

# %%
print("From test dataset")
(X,y) = test_gen.__getitem__(8996)
view_images(X,y)

print("\nFrom Training dataset")
(X,y) = train_gen.__getitem__(35)
view_images(X,y,1)

print("\nFrom validation dataset")
(X,y) = val_gen.__getitem__(11)
view_images(X,y,1)
# Out:
# From test dataset
# Label:  1.0
#
# From Training dataset
# Label:  1.0
#
# From validation dataset
# Label:  1.0

# %% [markdown]
# ## Loading samples of "no damage" class images

# %%
print("From test dataset")
(X,y) = test_gen.__getitem__(6)
view_images(X,y)

print("\nFrom Training dataset")
(X,y) = train_gen.__getitem__(5)
view_images(X,y,1)

print("\nFrom validation dataset")
(X,y) = val_gen.__getitem__(2)
view_images(X,y,1)
# Out:
# From test dataset
# Label:  0.0
#
# From Training dataset
# Label:  0.0
#
# From validation dataset
# Label:  0.0

# %% [markdown]
# # Part 3. Defining the model architecture

# %% [markdown]
# 3.a. Defining some variables

# %%
# Locations for saving models
MODEL_DIR = 'project_models/checkpoints2/model_at_{epoch:02d}.ckpt'
BEST_DIR = 'project_models/checkpoints2/best/best_model.ckpt'
os.makedirs(os.path.dirname(MODEL_DIR), exist_ok=True)
os.makedirs(os.path.dirname(BEST_DIR), exist_ok=True)

#loss function
loss = tf.keras.losses.BinaryCrossentropy(from_logits = False)

#optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.0002)

#metrics
metrics = [tf.keras.metrics.BinaryAccuracy(threshold = 0.6)]

#callbacks
early_stop = tf.keras.callbacks.EarlyStopping(patience=20)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(MODEL_DIR)
best_checkpoint = tf.keras.callbacks.ModelCheckpoint(BEST_DIR, save_best_only=True)

# %% [markdown]
# 3.b. Model architecture

# %%
img_input = tf.keras.layers.Input((128,128,3))
base_model = tf.keras.applications.VGG16(include_top=False, weights='imagenet',
                                        input_tensor = img_input)
X = base_model.output
#Lock weights value
base_model.trainable = False

#Flatten
#Flatten
fl1 = tf.keras.layers.Flatten()(X)
dense1 = tf.keras.layers.Dense(100,activation='relu')(fl1)
output = tf.keras.layers.Dense(1,activation='sigmoid')(dense1)

#model creation
model = tf.keras.Model(inputs=img_input, outputs=output)
model.compile( optimizer=opt,loss=loss, metrics=metrics )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 10s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               819300
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 15,534,089
# Trainable params: 819,401
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
history = model.fit ( 
        train_gen,
        epochs =50,
        callbacks=[early_stop, model_checkpoint, best_checkpoint],
        validation_data = val_gen
                      )
# Out:
# Epoch 1/50
# 67/67 [==============================] - ETA: 0s - loss: 0.6643 - binary_accuracy: 0.5938WARNING:tensorflow:From D:\Programs\Anaconda\envs\tf-gpu-py37\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_01.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 60s 901ms/step - loss: 0.6643 - binary_accuracy: 0.5938 - val_loss: 0.5362 - val_binary_accuracy: 0.7755
# Epoch 2/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4495 - binary_accuracy: 0.7894INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_02.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 52s 774ms/step - loss: 0.4495 - binary_accuracy: 0.7894 - val_loss: 0.4228 - val_binary_accuracy: 0.7805
# Epoch 3/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4489 - binary_accuracy: 0.7831INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_03.ckpt\assets
# 67/67 [==============================] - 52s 778ms/step - loss: 0.4489 - binary_accuracy: 0.7831 - val_loss: 0.4261 - val_binary_accuracy: 0.8300
# Epoch 4/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4164 - binary_accuracy: 0.8097INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_04.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 832ms/step - loss: 0.4164 - binary_accuracy: 0.8097 - val_loss: 0.3799 - val_binary_accuracy: 0.8455
# Epoch 5/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3950 - binary_accuracy: 0.8173INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_05.ckpt\assets
# 67/67 [==============================] - 50s 748ms/step - loss: 0.3950 - binary_accuracy: 0.8173 - val_loss: 0.3894 - val_binary_accuracy: 0.8505
# Epoch 6/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4196 - binary_accuracy: 0.8135INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_06.ckpt\assets
# 67/67 [==============================] - 51s 763ms/step - loss: 0.4196 - binary_accuracy: 0.8135 - val_loss: 0.3989 - val_binary_accuracy: 0.7895
# Epoch 7/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3933 - binary_accuracy: 0.8177INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_07.ckpt\assets
# 67/67 [==============================] - 51s 768ms/step - loss: 0.3933 - binary_accuracy: 0.8177 - val_loss: 0.4586 - val_binary_accuracy: 0.7510
# Epoch 8/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3942 - binary_accuracy: 0.8217INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_08.ckpt\assets
# 67/67 [==============================] - 54s 800ms/step - loss: 0.3942 - binary_accuracy: 0.8217 - val_loss: 0.4059 - val_binary_accuracy: 0.7835
# Epoch 9/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3758 - binary_accuracy: 0.8269INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_09.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 825ms/step - loss: 0.3758 - binary_accuracy: 0.8269 - val_loss: 0.3588 - val_binary_accuracy: 0.8190
# Epoch 10/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3811 - binary_accuracy: 0.8230INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_10.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 54s 807ms/step - loss: 0.3811 - binary_accuracy: 0.8230 - val_loss: 0.3415 - val_binary_accuracy: 0.8585
# Epoch 11/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3799 - binary_accuracy: 0.8319INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_11.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 54s 813ms/step - loss: 0.3799 - binary_accuracy: 0.8319 - val_loss: 0.3329 - val_binary_accuracy: 0.8640
# Epoch 12/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3633 - binary_accuracy: 0.8394INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_12.ckpt\assets
# 67/67 [==============================] - 52s 775ms/step - loss: 0.3633 - binary_accuracy: 0.8394 - val_loss: 0.3627 - val_binary_accuracy: 0.8160
# Epoch 13/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3955 - binary_accuracy: 0.8165INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_13.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 833ms/step - loss: 0.3955 - binary_accuracy: 0.8165 - val_loss: 0.3312 - val_binary_accuracy: 0.8580
# Epoch 14/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3591 - binary_accuracy: 0.8336INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_14.ckpt\assets
# 67/67 [==============================] - 52s 781ms/step - loss: 0.3591 - binary_accuracy: 0.8336 - val_loss: 0.3344 - val_binary_accuracy: 0.8555
# Epoch 15/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3610 - binary_accuracy: 0.8348INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_15.ckpt\assets
# 67/67 [==============================] - 53s 794ms/step - loss: 0.3610 - binary_accuracy: 0.8348 - val_loss: 0.3405 - val_binary_accuracy: 0.8535
# Epoch 16/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3517 - binary_accuracy: 0.8449INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_16.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 57s 851ms/step - loss: 0.3517 - binary_accuracy: 0.8449 - val_loss: 0.3307 - val_binary_accuracy: 0.8390
# Epoch 17/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3510 - binary_accuracy: 0.8374INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_17.ckpt\assets
# 67/67 [==============================] - 53s 798ms/step - loss: 0.3510 - binary_accuracy: 0.8374 - val_loss: 0.3408 - val_binary_accuracy: 0.8665
# Epoch 18/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3555 - binary_accuracy: 0.8458INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_18.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 829ms/step - loss: 0.3555 - binary_accuracy: 0.8458 - val_loss: 0.3179 - val_binary_accuracy: 0.8475
# Epoch 19/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3548 - binary_accuracy: 0.8386INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_19.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 824ms/step - loss: 0.3548 - binary_accuracy: 0.8386 - val_loss: 0.3162 - val_binary_accuracy: 0.8655
# Epoch 20/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3669 - binary_accuracy: 0.8307INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_20.ckpt\assets
# 67/67 [==============================] - 53s 785ms/step - loss: 0.3669 - binary_accuracy: 0.8307 - val_loss: 0.3231 - val_binary_accuracy: 0.8495
# Epoch 21/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3426 - binary_accuracy: 0.8438INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_21.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 829ms/step - loss: 0.3426 - binary_accuracy: 0.8438 - val_loss: 0.3112 - val_binary_accuracy: 0.8560
# Epoch 22/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3297 - binary_accuracy: 0.8542INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_22.ckpt\assets
# 67/67 [==============================] - 53s 785ms/step - loss: 0.3297 - binary_accuracy: 0.8542 - val_loss: 0.3754 - val_binary_accuracy: 0.7970
# Epoch 23/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3348 - binary_accuracy: 0.8454INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_23.ckpt\assets
# 67/67 [==============================] - 54s 811ms/step - loss: 0.3348 - binary_accuracy: 0.8454 - val_loss: 0.3209 - val_binary_accuracy: 0.8670
# Epoch 24/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3282 - binary_accuracy: 0.8463INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_24.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 57s 847ms/step - loss: 0.3282 - binary_accuracy: 0.8463 - val_loss: 0.3109 - val_binary_accuracy: 0.8595
# Epoch 25/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3145 - binary_accuracy: 0.8636INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_25.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 833ms/step - loss: 0.3145 - binary_accuracy: 0.8636 - val_loss: 0.3096 - val_binary_accuracy: 0.8680
# Epoch 26/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3318 - binary_accuracy: 0.8527INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_26.ckpt\assets
# 67/67 [==============================] - 59s 885ms/step - loss: 0.3318 - binary_accuracy: 0.8527 - val_loss: 0.3184 - val_binary_accuracy: 0.8520
# Epoch 27/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3024 - binary_accuracy: 0.8613INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_27.ckpt\assets
# 67/67 [==============================] - 52s 783ms/step - loss: 0.3024 - binary_accuracy: 0.8613 - val_loss: 0.3300 - val_binary_accuracy: 0.8710
# Epoch 28/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3514 - binary_accuracy: 0.8439INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_28.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 57s 851ms/step - loss: 0.3514 - binary_accuracy: 0.8439 - val_loss: 0.3046 - val_binary_accuracy: 0.8705
# Epoch 29/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3372 - binary_accuracy: 0.8437INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_29.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 839ms/step - loss: 0.3372 - binary_accuracy: 0.8437 - val_loss: 0.2922 - val_binary_accuracy: 0.8760
# Epoch 30/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3348 - binary_accuracy: 0.8525INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_30.ckpt\assets
# 67/67 [==============================] - 53s 791ms/step - loss: 0.3348 - binary_accuracy: 0.8525 - val_loss: 0.3414 - val_binary_accuracy: 0.8270
# Epoch 31/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3268 - binary_accuracy: 0.8547INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_31.ckpt\assets
# 67/67 [==============================] - 54s 799ms/step - loss: 0.3268 - binary_accuracy: 0.8547 - val_loss: 0.3054 - val_binary_accuracy: 0.8655
# Epoch 32/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3220 - binary_accuracy: 0.8492INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_32.ckpt\assets
# 67/67 [==============================] - 54s 800ms/step - loss: 0.3220 - binary_accuracy: 0.8492 - val_loss: 0.3288 - val_binary_accuracy: 0.8390
# Epoch 33/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3275 - binary_accuracy: 0.8497INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_33.ckpt\assets
# 67/67 [==============================] - 53s 790ms/step - loss: 0.3275 - binary_accuracy: 0.8497 - val_loss: 0.4100 - val_binary_accuracy: 0.7815
# Epoch 34/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3304 - binary_accuracy: 0.8516INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_34.ckpt\assets
# 67/67 [==============================] - 53s 794ms/step - loss: 0.3304 - binary_accuracy: 0.8516 - val_loss: 0.2932 - val_binary_accuracy: 0.8665
# Epoch 35/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3136 - binary_accuracy: 0.8604INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_35.ckpt\assets
# 67/67 [==============================] - 53s 797ms/step - loss: 0.3136 - binary_accuracy: 0.8604 - val_loss: 0.3202 - val_binary_accuracy: 0.8330
# Epoch 36/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3046 - binary_accuracy: 0.8634INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_36.ckpt\assets
# 67/67 [==============================] - 53s 794ms/step - loss: 0.3046 - binary_accuracy: 0.8634 - val_loss: 0.3056 - val_binary_accuracy: 0.8480
# Epoch 37/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3420 - binary_accuracy: 0.8473INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_37.ckpt\assets
# 67/67 [==============================] - 53s 794ms/step - loss: 0.3420 - binary_accuracy: 0.8473 - val_loss: 0.3042 - val_binary_accuracy: 0.8610
# Epoch 38/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3050 - binary_accuracy: 0.8625INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_38.ckpt\assets
# 67/67 [==============================] - 54s 800ms/step - loss: 0.3050 - binary_accuracy: 0.8625 - val_loss: 0.3054 - val_binary_accuracy: 0.8655
# Epoch 39/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3116 - binary_accuracy: 0.8617INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_39.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 835ms/step - loss: 0.3116 - binary_accuracy: 0.8617 - val_loss: 0.2899 - val_binary_accuracy: 0.8610
# Epoch 40/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3276 - binary_accuracy: 0.8474INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_40.ckpt\assets
# 67/67 [==============================] - 53s 792ms/step - loss: 0.3276 - binary_accuracy: 0.8474 - val_loss: 0.2910 - val_binary_accuracy: 0.8620
# Epoch 41/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3092 - binary_accuracy: 0.8579INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_41.ckpt\assets
# 67/67 [==============================] - 55s 821ms/step - loss: 0.3092 - binary_accuracy: 0.8579 - val_loss: 0.3546 - val_binary_accuracy: 0.8540
# Epoch 42/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3258 - binary_accuracy: 0.8535INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_42.ckpt\assets
# 67/67 [==============================] - 54s 811ms/step - loss: 0.3258 - binary_accuracy: 0.8535 - val_loss: 0.2979 - val_binary_accuracy: 0.8660
# Epoch 43/50
# 67/67 [==============================] - ETA: 0s - loss: 0.2955 - binary_accuracy: 0.8726INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_43.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints2/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 832ms/step - loss: 0.2955 - binary_accuracy: 0.8726 - val_loss: 0.2746 - val_binary_accuracy: 0.8775
# Epoch 44/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3038 - binary_accuracy: 0.8623INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_44.ckpt\assets
# 67/67 [==============================] - 57s 847ms/step - loss: 0.3038 - binary_accuracy: 0.8623 - val_loss: 0.2965 - val_binary_accuracy: 0.8645
# Epoch 45/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3109 - binary_accuracy: 0.8657INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_45.ckpt\assets
# 67/67 [==============================] - 53s 795ms/step - loss: 0.3109 - binary_accuracy: 0.8657 - val_loss: 0.3407 - val_binary_accuracy: 0.8105
# Epoch 46/50
# 67/67 [==============================] - ETA: 0s - loss: 0.2984 - binary_accuracy: 0.8617INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_46.ckpt\assets
# 67/67 [==============================] - 53s 788ms/step - loss: 0.2984 - binary_accuracy: 0.8617 - val_loss: 0.2878 - val_binary_accuracy: 0.8610
# Epoch 47/50
# 67/67 [==============================] - ETA: 0s - loss: 0.2938 - binary_accuracy: 0.8739INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_47.ckpt\assets
# 67/67 [==============================] - 54s 799ms/step - loss: 0.2938 - binary_accuracy: 0.8739 - val_loss: 0.3128 - val_binary_accuracy: 0.8455
# Epoch 48/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3110 - binary_accuracy: 0.8585INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_48.ckpt\assets
# 67/67 [==============================] - 54s 800ms/step - loss: 0.3110 - binary_accuracy: 0.8585 - val_loss: 0.2822 - val_binary_accuracy: 0.8810
# Epoch 49/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3072 - binary_accuracy: 0.8660INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_49.ckpt\assets
# 67/67 [==============================] - 54s 812ms/step - loss: 0.3072 - binary_accuracy: 0.8660 - val_loss: 0.3904 - val_binary_accuracy: 0.7950
# Epoch 50/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3399 - binary_accuracy: 0.8444INFO:tensorflow:Assets written to: project_models/checkpoints2/model_at_50.ckpt\assets
# 67/67 [==============================] - 53s 791ms/step - loss: 0.3399 - binary_accuracy: 0.8444 - val_loss: 0.2818 - val_binary_accuracy: 0.8640

# %% [markdown]
# # Part 3. Visualizing Results

# %% [markdown]
# 3.a. Charts for training and validation metrics

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,6))

axes[0].plot(history.history[('binary_accuracy')])
axes[0].plot(history.history[('val_binary_accuracy')])
axes[0].legend(['training', 'validation'])
axes[0].set_title("Training and Validation Accuracy")
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('accuracy')
axes[0].set_ylim([0,1])

axes[1].plot(history.history[('loss')])
axes[1].plot(history.history[('val_loss')])
axes[1].legend(['training', 'validation'])
axes[1].set_title("Training and Validation loss")
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('loss')
axes[1].set_ylim([0,2])



plt.show()

# %% [markdown]
# 3.b. Loading the Best Model

# %%
best_model = tf.keras.models.load_model(BEST_DIR)

# %% [markdown]
# 3.c. Loading a test dataset with 2000 items

# %%
TEST_LOC_LIGHT= "../../datasets/sat_images/test"

test_idg_light = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1/255)

test_gen_light = test_idg_light.flow_from_directory(TEST_LOC_LIGHT, IMG_SIZE,
                                         class_mode='binary', classes=classes,
                                         color_mode='rgb',   shuffle=False,
                                         batch_size=1
                                        )
# Out:
# Found 2000 images belonging to 2 classes.

# %%
test_X, test_y = view_generator_data(test_gen_light, test_gen_light.n)

# %% [markdown]
# 3.d. Predictions from test data

# %%
y_pred = best_model.predict(test_X)
y_pred.reshape(2000,)
# Out:
# array([0.9002695 , 0.26613486, 0.21167283, ..., 0.57526004, 0.94966906,
#        0.96302253], dtype=float32)

# %%
roc_auc_score(test_y, y_pred)
# Out:
# 0.9477720000000001

# %% [markdown]
# ### 3.e. Metrics
# PRECISION - RECALL CURVE

# %%
pr, r, thr = precision_recall_curve(test_y, y_pred)

# %% [markdown]
# ROC CURVE

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thres = roc_curve(test_y, y_pred, pos_label=1)

# %%
fig,ax = plt.subplots(figsize=(16,6), ncols=2)

ax[0].plot( fpr,tpr)
ax[0].set_title("Receiver Operating Characteritics")
ax[0].set_xlabel("false positive rate")
ax[0].set_ylabel("true positive rate")


ax[1].plot(thr, pr[:-1])
ax[1].plot(thr, r[:-1])
ax[1].set_xlabel('threshold')
ax[1].set_ylabel('value')
plt.axvline(x=0.45, color='k')
ax[1].legend(["precision", 'recall'])
ax[1].set_title("Precision Recall Curve")
plt.show()

# %%
threshold = 0.45
accuracy_score(test_y > threshold, y_pred > threshold)
# Out:
# 0.8715

# %% [markdown]
# CLASSIFICATION REPORT

# %%
print(classification_report(test_y>threshold, y_pred > threshold))
cm = confusion_matrix(test_y>threshold, y_pred > threshold)
sns.heatmap(cm, annot=True, fmt="g")
plt.ylabel('True')
plt.xlabel('Pred')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        False       0.87      0.88      0.87      1000
#         True       0.87      0.87      0.87      1000
#
#     accuracy                           0.87      2000
#    macro avg       0.87      0.87      0.87      2000
# weighted avg       0.87      0.87      0.87      2000
