# %% [markdown]
# Author: Nikko V. salcedo
# This is a classification model development using keras and tensorflow to detect hurricane damage using satellite images.
#
# Available dataset:
# Training - 10,0000
# Validation - 2,000
# Test - 9,000
#
# Image resolution is at (256X256)

# %% [markdown]
# # Part 1. Import all needed packages

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, classification_report, precision_recall_curve
import seaborn as sns
import tensorflow as tf
import numpy as np
import os
import PIL
import PIL.Image
import random
import matplotlib.pyplot as plt
sns.set()

# %% [markdown]
# # Part 2. Pre-procesing
# a. Image resizing: (256, 256) -> (128, 128)
# b. Grayscale: None
# c. Augmentations: None
# d. Shufflled: None

# %%
# Dataset Image paths
TEST_LOC= "../../datasets/sat_images/test_another"
TRAIN_LOC = "../../datasets/sat_images/train_another"
VAL_LOC = "../../datasets/sat_images/validation_another"

#Other global variables:
IMG_SIZE = (128,128)
BATCH_SIZE = 150
classes = {'no_damage':0, 'damage': 1,}

#Image Data Generator Objects

""" 
Augmentations done on trianing data:
1. rotation
2. zoom
3. reflect
4. vertical flip
5. horizontal flip
6. rescale

This is to avoid overfitting
"""
train_idg = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=360,
    zoom_range=0.5,
    fill_mode='reflect',
    horizontal_flip=True,
    vertical_flip=True,
    rescale=1.0/255
)

test_idg =tf.keras.preprocessing.image.ImageDataGenerator( rescale=1.0/255)

#creating the datasets

train_gen = train_idg.flow_from_directory(TRAIN_LOC, IMG_SIZE,
                                         class_mode='binary', classes=classes,
                                         color_mode='rgb', shuffle=False,
                                         batch_size=BATCH_SIZE
                                         )

val_gen = train_idg.flow_from_directory(VAL_LOC, IMG_SIZE,
                                         class_mode='binary', classes=classes,
                                         color_mode='rgb', shuffle=False,
                                         batch_size=BATCH_SIZE
                                         )
test_gen = test_idg.flow_from_directory(TEST_LOC, IMG_SIZE,
                                         class_mode='binary', classes=classes,
                                         color_mode='rgb', shuffle=False,
                                         batch_size=1
                                         )
# Out:
# Found 10000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Found 9000 images belonging to 2 classes.

# %% [markdown]
# ### Some functions for unpacking and viewing the data

# %%
def view_generator_data(gen, n):
    data = [next(gen) for _ in range(n)]
    data = list(zip(*data))
    X, y = data
    X = np.concatenate(X, axis=0)
    y = np.concatenate(y, axis=0)
    return X, y

def view_images(X, y, n=None):
    n = n or len(X)
    for i in range(n):
        plt.imshow(X[i])
        plt.grid(None)
        plt.show()
        print('Label: ', y[i])
test_gen.__len__()
# Out:
# 9000

# %% [markdown]
# ## Loading sample images for "damaged" class

# %%
print("From test dataset")
(X,y) = test_gen.__getitem__(8996)
view_images(X,y)

print("\nFrom Training dataset")
(X,y) = train_gen.__getitem__(35)
view_images(X,y,1)

print("\nFrom validation dataset")
(X,y) = val_gen.__getitem__(11)
view_images(X,y,1)
# Out:
# From test dataset
# Label:  1.0
#
# From Training dataset
# Label:  1.0
#
# From validation dataset
# Label:  1.0

# %% [markdown]
# ## Loading samples of "no damage" class images

# %%
print("From test dataset")
(X,y) = test_gen.__getitem__(6)
view_images(X,y)

print("\nFrom Training dataset")
(X,y) = train_gen.__getitem__(5)
view_images(X,y,1)

print("\nFrom validation dataset")
(X,y) = val_gen.__getitem__(2)
view_images(X,y,1)
# Out:
# From test dataset
# Label:  0.0
#
# From Training dataset
# Label:  0.0
#
# From validation dataset
# Label:  0.0

# %% [markdown]
# # Part 3. Defining the model architecture

# %% [markdown]
# 3.a. Defining some variables

# %%
# Locations for saving models
MODEL_DIR = 'project_models/checkpoints4/model_at_{epoch:02d}.ckpt'
BEST_DIR = 'project_models/checkpoints4/best/best_model.ckpt'
os.makedirs(os.path.dirname(MODEL_DIR), exist_ok=True)
os.makedirs(os.path.dirname(BEST_DIR), exist_ok=True)

#loss function
loss = tf.keras.losses.BinaryCrossentropy(from_logits = False)

#optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.0015)

#metrics
metrics = [tf.keras.metrics.BinaryAccuracy(threshold = 0.6)]

#callbacks
early_stop = tf.keras.callbacks.EarlyStopping(patience=20)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(MODEL_DIR)
best_checkpoint = tf.keras.callbacks.ModelCheckpoint(BEST_DIR, save_best_only=True)

# %% [markdown]
# 3.b. Model architecture

# %%
img_input = tf.keras.layers.Input((128,128,3))
base_model = tf.keras.applications.MobileNet(include_top=False, weights='imagenet',
                                        input_tensor = img_input)
X = base_model.output
#Lock weights value
base_model.trainable = False

#Flatten
#Flatten
fl1 = tf.keras.layers.Flatten()(X)
dense1 = tf.keras.layers.Dense(100,activation='relu')(fl1)
output = tf.keras.layers.Dense(1,activation='sigmoid')(dense1)

#model creation
model = tf.keras.Model(inputs=img_input, outputs=output)
model.compile( optimizer=opt,loss=loss, metrics=metrics )
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 129, 129, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 64, 64, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 64, 64, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 64, 64, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 64, 64, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 64, 64, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 64, 64, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 64, 64, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 64, 64, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 65, 65, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 32, 32, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 32, 32, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 32, 32, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 32, 32, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 32, 32, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 32, 32, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 32, 32, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 32, 32, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 32, 32, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 32, 32, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 32, 32, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 32, 32, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 33, 33, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 16, 16, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 16, 16, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 16, 16, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 16, 16, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 16, 16, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 16, 16, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 16, 16, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 17, 17, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 8, 8, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 8, 8, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 8, 8, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 9, 9, 512)         0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 4, 4, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 4, 4, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 4, 4, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 4, 4, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 4, 4, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 4, 4, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 4, 4, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 4, 4, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 4, 4, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 100)               1638500
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 4,867,465
# Trainable params: 1,638,601
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
history = model.fit ( 
        train_gen,
        epochs =50,
        callbacks=[early_stop, model_checkpoint, best_checkpoint],
        validation_data = val_gen
                      )
# Out:
# Epoch 1/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9042 - binary_accuracy: 0.6943WARNING:tensorflow:From D:\Programs\Anaconda\envs\tf-gpu-py37\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_01.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 54s 803ms/step - loss: 1.9042 - binary_accuracy: 0.6943 - val_loss: 0.5964 - val_binary_accuracy: 0.7480
# Epoch 2/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5578 - binary_accuracy: 0.7959INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_02.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 54s 802ms/step - loss: 0.5578 - binary_accuracy: 0.7959 - val_loss: 0.5263 - val_binary_accuracy: 0.8330
# Epoch 3/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5359 - binary_accuracy: 0.8117INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_03.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 821ms/step - loss: 0.5359 - binary_accuracy: 0.8117 - val_loss: 0.5145 - val_binary_accuracy: 0.8175
# Epoch 4/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4873 - binary_accuracy: 0.8498INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_04.ckpt\assets
# 67/67 [==============================] - 47s 702ms/step - loss: 0.4873 - binary_accuracy: 0.8498 - val_loss: 0.5368 - val_binary_accuracy: 0.8430
# Epoch 5/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5160 - binary_accuracy: 0.8066INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_05.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 54s 812ms/step - loss: 0.5160 - binary_accuracy: 0.8066 - val_loss: 0.4918 - val_binary_accuracy: 0.8225
# Epoch 6/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4786 - binary_accuracy: 0.8402INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_06.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 814ms/step - loss: 0.4786 - binary_accuracy: 0.8402 - val_loss: 0.4636 - val_binary_accuracy: 0.8490
# Epoch 7/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4952 - binary_accuracy: 0.8283INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_07.ckpt\assets
# 67/67 [==============================] - 47s 704ms/step - loss: 0.4952 - binary_accuracy: 0.8283 - val_loss: 0.5008 - val_binary_accuracy: 0.7910
# Epoch 8/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4662 - binary_accuracy: 0.8403INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_08.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 842ms/step - loss: 0.4662 - binary_accuracy: 0.8403 - val_loss: 0.4478 - val_binary_accuracy: 0.8540
# Epoch 9/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4492 - binary_accuracy: 0.8565INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_09.ckpt\assets
# 67/67 [==============================] - 47s 707ms/step - loss: 0.4492 - binary_accuracy: 0.8565 - val_loss: 0.4526 - val_binary_accuracy: 0.8450
# Epoch 10/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4591 - binary_accuracy: 0.8439INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_10.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 814ms/step - loss: 0.4591 - binary_accuracy: 0.8439 - val_loss: 0.4427 - val_binary_accuracy: 0.8485
# Epoch 11/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4245 - binary_accuracy: 0.8681INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_11.ckpt\assets
# 67/67 [==============================] - 47s 704ms/step - loss: 0.4245 - binary_accuracy: 0.8681 - val_loss: 0.4519 - val_binary_accuracy: 0.8785
# Epoch 12/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4139 - binary_accuracy: 0.8843INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_12.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 830ms/step - loss: 0.4139 - binary_accuracy: 0.8843 - val_loss: 0.4209 - val_binary_accuracy: 0.8715
# Epoch 13/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4260 - binary_accuracy: 0.8667INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_13.ckpt\assets
# 67/67 [==============================] - 47s 705ms/step - loss: 0.4260 - binary_accuracy: 0.8667 - val_loss: 0.4652 - val_binary_accuracy: 0.8055
# Epoch 14/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4361 - binary_accuracy: 0.8472INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_14.ckpt\assets
# 67/67 [==============================] - 47s 700ms/step - loss: 0.4361 - binary_accuracy: 0.8472 - val_loss: 0.4211 - val_binary_accuracy: 0.8485
# Epoch 15/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4406 - binary_accuracy: 0.8430INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_15.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 827ms/step - loss: 0.4406 - binary_accuracy: 0.8430 - val_loss: 0.4120 - val_binary_accuracy: 0.8525
# Epoch 16/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3990 - binary_accuracy: 0.8712INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_16.ckpt\assets
# 67/67 [==============================] - 47s 705ms/step - loss: 0.3990 - binary_accuracy: 0.8712 - val_loss: 0.4404 - val_binary_accuracy: 0.8825
# Epoch 17/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4026 - binary_accuracy: 0.8731INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_17.ckpt\assets
# 67/67 [==============================] - 47s 704ms/step - loss: 0.4026 - binary_accuracy: 0.8731 - val_loss: 0.4169 - val_binary_accuracy: 0.8455
# Epoch 18/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3934 - binary_accuracy: 0.8695INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_18.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 821ms/step - loss: 0.3934 - binary_accuracy: 0.8695 - val_loss: 0.3799 - val_binary_accuracy: 0.8845
# Epoch 19/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3862 - binary_accuracy: 0.8770INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_19.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 828ms/step - loss: 0.3862 - binary_accuracy: 0.8770 - val_loss: 0.3664 - val_binary_accuracy: 0.8955
# Epoch 20/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3960 - binary_accuracy: 0.8666INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_20.ckpt\assets
# 67/67 [==============================] - 48s 714ms/step - loss: 0.3960 - binary_accuracy: 0.8666 - val_loss: 0.3770 - val_binary_accuracy: 0.8800
# Epoch 21/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3653 - binary_accuracy: 0.8926INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_21.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 826ms/step - loss: 0.3653 - binary_accuracy: 0.8926 - val_loss: 0.3552 - val_binary_accuracy: 0.8965
# Epoch 22/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3733 - binary_accuracy: 0.8800INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_22.ckpt\assets
# 67/67 [==============================] - 47s 708ms/step - loss: 0.3733 - binary_accuracy: 0.8800 - val_loss: 0.3764 - val_binary_accuracy: 0.8735
# Epoch 23/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3741 - binary_accuracy: 0.8826INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_23.ckpt\assets
# 67/67 [==============================] - 47s 700ms/step - loss: 0.3741 - binary_accuracy: 0.8826 - val_loss: 0.4290 - val_binary_accuracy: 0.8175
# Epoch 24/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3805 - binary_accuracy: 0.8662INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_24.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 54s 812ms/step - loss: 0.3805 - binary_accuracy: 0.8662 - val_loss: 0.3522 - val_binary_accuracy: 0.8870
# Epoch 25/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3649 - binary_accuracy: 0.8829INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_25.ckpt\assets
# 67/67 [==============================] - 48s 722ms/step - loss: 0.3649 - binary_accuracy: 0.8829 - val_loss: 0.4130 - val_binary_accuracy: 0.8200
# Epoch 26/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3716 - binary_accuracy: 0.8693INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_26.ckpt\assets
# 67/67 [==============================] - 50s 739ms/step - loss: 0.3716 - binary_accuracy: 0.8693 - val_loss: 0.3556 - val_binary_accuracy: 0.8975
# Epoch 27/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3500 - binary_accuracy: 0.8840INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_27.ckpt\assets
# 67/67 [==============================] - 47s 705ms/step - loss: 0.3500 - binary_accuracy: 0.8840 - val_loss: 0.3534 - val_binary_accuracy: 0.8855
# Epoch 28/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3409 - binary_accuracy: 0.8928INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_28.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 826ms/step - loss: 0.3409 - binary_accuracy: 0.8928 - val_loss: 0.3504 - val_binary_accuracy: 0.8825
# Epoch 29/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3495 - binary_accuracy: 0.8849INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_29.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 838ms/step - loss: 0.3495 - binary_accuracy: 0.8849 - val_loss: 0.3463 - val_binary_accuracy: 0.9060
# Epoch 30/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3331 - binary_accuracy: 0.8951INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_30.ckpt\assets
# 67/67 [==============================] - 48s 710ms/step - loss: 0.3331 - binary_accuracy: 0.8951 - val_loss: 0.3512 - val_binary_accuracy: 0.8970
# Epoch 31/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3413 - binary_accuracy: 0.8894INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_31.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 814ms/step - loss: 0.3413 - binary_accuracy: 0.8894 - val_loss: 0.3400 - val_binary_accuracy: 0.8950
# Epoch 32/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3493 - binary_accuracy: 0.8806INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_32.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 816ms/step - loss: 0.3493 - binary_accuracy: 0.8806 - val_loss: 0.3262 - val_binary_accuracy: 0.9015
# Epoch 33/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3449 - binary_accuracy: 0.8853INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_33.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 831ms/step - loss: 0.3449 - binary_accuracy: 0.8853 - val_loss: 0.3248 - val_binary_accuracy: 0.8960
# Epoch 34/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3277 - binary_accuracy: 0.8908INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_34.ckpt\assets
# 67/67 [==============================] - 47s 697ms/step - loss: 0.3277 - binary_accuracy: 0.8908 - val_loss: 0.3263 - val_binary_accuracy: 0.8900
# Epoch 35/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3462 - binary_accuracy: 0.8819INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_35.ckpt\assets
# 67/67 [==============================] - 48s 718ms/step - loss: 0.3462 - binary_accuracy: 0.8819 - val_loss: 0.3627 - val_binary_accuracy: 0.8550
# Epoch 36/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3443 - binary_accuracy: 0.8802INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_36.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 823ms/step - loss: 0.3443 - binary_accuracy: 0.8802 - val_loss: 0.3195 - val_binary_accuracy: 0.8980
# Epoch 37/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3176 - binary_accuracy: 0.8943INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_37.ckpt\assets
# 67/67 [==============================] - 48s 712ms/step - loss: 0.3176 - binary_accuracy: 0.8943 - val_loss: 0.3264 - val_binary_accuracy: 0.8830
# Epoch 38/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3219 - binary_accuracy: 0.8934INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_38.ckpt\assets
# 67/67 [==============================] - 48s 717ms/step - loss: 0.3219 - binary_accuracy: 0.8934 - val_loss: 0.3215 - val_binary_accuracy: 0.8805
# Epoch 39/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3163 - binary_accuracy: 0.8948INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_39.ckpt\assets
# 67/67 [==============================] - 48s 721ms/step - loss: 0.3163 - binary_accuracy: 0.8948 - val_loss: 0.3268 - val_binary_accuracy: 0.8945
# Epoch 40/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3153 - binary_accuracy: 0.8933INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_40.ckpt\assets
# 67/67 [==============================] - 48s 720ms/step - loss: 0.3153 - binary_accuracy: 0.8933 - val_loss: 0.3324 - val_binary_accuracy: 0.9030
# Epoch 41/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3389 - binary_accuracy: 0.8793INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_41.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 829ms/step - loss: 0.3389 - binary_accuracy: 0.8793 - val_loss: 0.3064 - val_binary_accuracy: 0.8970
# Epoch 42/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3307 - binary_accuracy: 0.8821INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_42.ckpt\assets
# 67/67 [==============================] - 49s 735ms/step - loss: 0.3307 - binary_accuracy: 0.8821 - val_loss: 0.3076 - val_binary_accuracy: 0.8970
# Epoch 43/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3046 - binary_accuracy: 0.8956INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_43.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 56s 837ms/step - loss: 0.3046 - binary_accuracy: 0.8956 - val_loss: 0.3001 - val_binary_accuracy: 0.9035
# Epoch 44/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3113 - binary_accuracy: 0.8943INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_44.ckpt\assets
# 67/67 [==============================] - 48s 716ms/step - loss: 0.3113 - binary_accuracy: 0.8943 - val_loss: 0.3180 - val_binary_accuracy: 0.8835
# Epoch 45/50
# 67/67 [==============================] - ETA: 0s - loss: 0.2964 - binary_accuracy: 0.9000INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_45.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 827ms/step - loss: 0.2964 - binary_accuracy: 0.9000 - val_loss: 0.2967 - val_binary_accuracy: 0.9020
# Epoch 46/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3084 - binary_accuracy: 0.8923INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_46.ckpt\assets
# INFO:tensorflow:Assets written to: project_models/checkpoints4/best/best_model.ckpt\assets
# 67/67 [==============================] - 55s 824ms/step - loss: 0.3084 - binary_accuracy: 0.8923 - val_loss: 0.2854 - val_binary_accuracy: 0.9050
# Epoch 47/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3239 - binary_accuracy: 0.8855INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_47.ckpt\assets
# 67/67 [==============================] - 47s 703ms/step - loss: 0.3239 - binary_accuracy: 0.8855 - val_loss: 0.3263 - val_binary_accuracy: 0.8710
# Epoch 48/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3116 - binary_accuracy: 0.8942INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_48.ckpt\assets
# 67/67 [==============================] - 48s 715ms/step - loss: 0.3116 - binary_accuracy: 0.8942 - val_loss: 0.3459 - val_binary_accuracy: 0.8570
# Epoch 49/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3076 - binary_accuracy: 0.8903INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_49.ckpt\assets
# 67/67 [==============================] - 50s 743ms/step - loss: 0.3076 - binary_accuracy: 0.8903 - val_loss: 0.3186 - val_binary_accuracy: 0.8825
# Epoch 50/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3014 - binary_accuracy: 0.8927INFO:tensorflow:Assets written to: project_models/checkpoints4/model_at_50.ckpt\assets
# 67/67 [==============================] - 47s 708ms/step - loss: 0.3014 - binary_accuracy: 0.8927 - val_loss: 0.2941 - val_binary_accuracy: 0.9010

# %% [markdown]
# # Part 3. Visualizing Results

# %% [markdown]
# 3.a. Charts for training and validation metrics

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,6))

axes[0].plot(history.history[('binary_accuracy')])
axes[0].plot(history.history[('val_binary_accuracy')])
axes[0].legend(['training', 'validation'])
axes[0].set_title("Training and Validation Accuracy")
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('accuracy')
axes[0].set_ylim([0,1])

axes[1].plot(history.history[('loss')])
axes[1].plot(history.history[('val_loss')])
axes[1].legend(['training', 'validation'])
axes[1].set_title("Training and Validation loss")
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('loss')
axes[1].set_ylim([0,2])



plt.show()

# %% [markdown]
# 3.b. Loading the Best Model

# %%
best_model = tf.keras.models.load_model(BEST_DIR)

# %% [markdown]
# 3.c. Loading a test dataset with 2000 items

# %%
TEST_LOC_LIGHT= "../../datasets/sat_images/test_light"

test_idg_light = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1/255)

test_gen_light = test_idg_light.flow_from_directory(TEST_LOC_LIGHT, IMG_SIZE,
                                         class_mode='binary', classes=classes,
                                         color_mode='rgb',   shuffle=False,
                                         batch_size=1
                                        )
# Out:
# Found 2000 images belonging to 2 classes.

# %%
test_X, test_y = view_generator_data(test_gen_light, test_gen_light.n)

# %% [markdown]
# 3.d. Predictions from test data

# %%
y_pred = best_model.predict(test_X)
y_pred.reshape(2000,)

# %%
roc_auc_score(test_y, y_pred)
# Out:
# 0.972786

# %% [markdown]
# ### 3.e. Metrics
# PRECISION - RECALL CURVE

# %%
pr, r, thr = precision_recall_curve(test_y, y_pred)

# %% [markdown]
# ROC CURVE

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thres = roc_curve(test_y, y_pred, pos_label=1)

# %%
fig,ax = plt.subplots(figsize=(16,6), ncols=2)

ax[0].plot( fpr,tpr)
ax[0].set_title("Receiver Operating Characteritics")
ax[0].set_xlabel("false positive rate")
ax[0].set_ylabel("true positive rate")


ax[1].plot(thr, pr[:-1])
ax[1].plot(thr, r[:-1])
ax[1].set_xlabel('threshold')
ax[1].set_ylabel('value')
plt.axvline(x=0.3, color='k')
ax[1].legend(["precision", 'recall'])
ax[1].set_title("Precision Recall Curve")
plt.show()

# %%
threshold = 0.3
accuracy_score(test_y > threshold, y_pred > threshold)
# Out:
# 0.949

# %% [markdown]
# CLASSIFICATION REPORT

# %%
print(classification_report(test_y>threshold, y_pred > threshold))
cm = confusion_matrix(test_y>threshold, y_pred > threshold)
sns.heatmap(cm, annot=True, fmt="g")
plt.ylabel('True')
plt.xlabel('Pred')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        False       0.95      0.95      0.95      1000
#         True       0.95      0.95      0.95      1000
#
#     accuracy                           0.95      2000
#    macro avg       0.95      0.95      0.95      2000
# weighted avg       0.95      0.95      0.95      2000
